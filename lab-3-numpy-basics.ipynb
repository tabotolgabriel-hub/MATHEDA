# %% [markdown]
# <b>Gabriel R. Tabotol</b>
# <br>Computer Engineer

# %%
# import and packages
import numpy as np

# %%
my_array = [1,2,3]

# %%
type(my_array)
# Out:
# list

# %%
my_array = np.array([1,2,3])

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# # 1D Array

# %%
my_array = np.array([1,2,3])

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# # 2D Array

# %%
my_array = np.array([
    [1,2,3]
    [4,5,6]
    ])
